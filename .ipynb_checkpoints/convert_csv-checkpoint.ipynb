# %%
import pandas as pd
import tabula
#pip install tabula-py

# %%
def convert_pdf_to_csv(filename):
    df = tabula.read_pdf(filename, pages='all')[0]
    tabula.convert_into(filename, "updated_df", output_format="csv", pages='all')
    return df

# %%
convert_pdf_to_csv("schedule.pdf")
# Out:
#                                            Unnamed: 0      Unnamed: 1  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2   niv of Il at Urbana-Champaign\revanagondi, Nee...             NaN
# 3                                               Title  Course Details
# 4                                 Discrete Structures      CS 173 BL2
# 5                                 Discrete Structures      CS 173 BDF
# 6                        Statistics and Probability I    STAT 400 FL1
# 7                        Statistics and Probability I    STAT 400 FD2
# 8                         Nature and American Culture     RST 242 ONA
# 9                        Intro to Computer Science II      CS 128 DBJ
# 10                           Indian Cinema in Context      CWL 207 A2
# 11                       Intro to Computer Science II      CS 128 AL1
# 12  Total Hours | Registered: 16 | Billing: 16 | C...             NaN
#
#    Univ of Il Urbana-Ch mpaign  \
# 0                   NaN    NaN
# 1                   NaN    NaN
# 2                   NaN    NaN
# 3          Credit Hours    CRN
# 4                   3.0  50094
# 5                   0.0  51089
# 6                   4.0  60237
# 7                   0.0  60241
# 8                   3.0  61458
# 9                   0.0  71604
# 10                  3.0  65011
# 11                  3.0  71594
# 12                  NaN    NaN
#
#                                            Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                                                 NaN         NaN         NaN
# 1                                                 NaN         NaN         NaN
# 2                                                 NaN         NaN         NaN
# 3                                       Meeting Times         NaN         NaN
# 4   01/18/2022 - 05/04/2022\rTuesday, Thursday\r12...         NaN         NaN
# 5   01/18/2022 - 05/04/2022\rFriday\r02:00 PM - 02...         NaN         NaN
# 6   01/18/2022 - 05/04/2022\rMonday, Wednesday, Fr...         NaN         NaN
# 7   01/18/2022 - 05/04/2022\rThursday\r11:00 AM - ...         NaN         NaN
# 8   01/18/2022 - 03/11/2022\rSantos, Carla\rJeong,...         NaN         NaN
# 9   01/18/2022 - 05/04/2022\rFriday\r10:30 AM - 11...         NaN         NaN
# 10  01/18/2022 - 05/04/2022\rMonday, Wednesday\r02...         NaN         NaN
# 11            01/18/2022 - 05/04/2022\rNowak, Michael         NaN         NaN
# 12                                                NaN         NaN         NaN
#
#     Neeyati Devanagondi (Neeya)
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
